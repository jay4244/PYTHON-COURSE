# %% [markdown]
# part - A Conditional statement

# %%
# 1. Write a program to check if a number is positive, negative, or zero.
num = int(input("Enter your number :"))
if num >0:
    print("number is positive")
elif num <0:
    print("number is nagative")
elif num==0:
    print("number is zero")
else:
    print("invalid number")
# Out:
# number is positive

# %%
# 2. Check whether a number is even or odd.
num = int(input("Enter your number :"))
if num%2==0:
    print("number is even",num)
else:
    print("number is odd",num)
# Out:
# number is even 12

# %%
# 3. Find the largest among three numbers.
num1 = int(input("Enter your number :"))
num2 = int(input("Enter your number :"))
num3 = int(input("Enter your number :"))
if num1 > num2:
    print(f"{num1} is greater than {num2}")
elif num2 > num3:
    print(f"{num2} is greater than {num3}")
else:
    print(f"{num3} is greater than {num1} and {num2}")
# Out:
# 25 is greater than 20

# %%
# 4. Check if a year is a leap year.
year = int(input("Enter your number :"))
if year%4==0:
    print(f"{year} is leap year")
else :
    print("year is not a leap year")
# Out:
# 2004 is leap year

# %%
# 5. Take marks from the user and print grade (A/B/C/D/F).
marks = int(input("Enter your marks :"))
if marks > 80:
    print(f"student grade is A")
elif marks > 70 and marks < 80:
    print(f"student grade is B")
elif marks > 60 and marks < 70:
    print(f"student grade is C")
elif marks > 40 and marks < 60:
    print(f"student grade is D")            
else:
    print(f"student grade is E")
# Out:
# student grade is C

# %%
# 6. Check whether a character is a vowel or consonant.
char = input("Enter your character :")
vowels = 'aeiouAEIOU'
if char in vowels:
    print(f"{char} is vowel")
else:
    print(f"{char} is consonant")
# Out:
# a is vowel

# %%
# 7. Check if a number is divisible by 5 and 11.
num = int(input("Enter your number :"))
if num%5==0 and num%11==0:
    print(f"{num} is divied by 5 and 11")
else :
    print("number is not divied")
# Out:
# 55 is divied by 5 and 11

# %%
# 8. Check if a person is eligible to vote (age ≥ 18).
age = int(input("Enter your age :"))
if age > 18 :
    print("you are aligable for vote")
else:
    print("you are not aligable for vote")
# Out:
# you are aligable for vote

# %%
# 9. Input a number and print whether it is a single, double, or triple-digit number.
num = int(input("Enter your number :"))
if num >0 and num <10:
    print("number is single digit") 
elif num >=10 and num <100:
    print("number is double digit") 
elif num >=100 and num <1000:
    print("number is triple digit")
else:
    print("number is more than three digit")
# Out:
# number is double digit

# %%
# 10. Check if a given number is a multiple of both 3 and 7.
num = int(input("Enter your number :"))
if num%3==0 and num%7==0:
    print(f"{num} is multiple by 3 and 7")
else:
    print("not multiple by 3 and 7 ")
# Out:
# 21 is multiple by 3 and 7

# %%
# 11. Accept a temperature in Celsius and print a message like “Cold”, “Moderate”, or “Hot”.
temp = int(input("Enter your temputcure : "))
if temp <0:
    print("temperature is cold")
elif temp >0 and temp <100 :
    print("temperature is moderate")
elif temp >100:
    print("temperature is hot")    
else:
    print("invalid tempeture")

# %%
# 12. Check whether a number is in range (1–100).
number = int(input("Enter your number :"))
if  number <=1 and number <=100:
    print(f"{number} in range of whether")
else:
    print(f"{number} is not in whether range")
# Out:
# 101 is not in whether range

# %%
# 13. Accept two numbers and print if their sum is greater than 100.
num1 = int(input("Enter your number :"))
num2 = int(input("Enter your number :"))
sum = num1 + num2
if  sum >=100:
    print(f"{num1} and {num2} is greater than 100")
else:
    print("sum less than 100")
# Out:
# sum less than 100

# %%
# 14. Check if a triangle is valid using its angles (sum == 180).
angles1 = int(input("Enter your angles :"))
angles2 = int(input("Enter your angles :"))
angles3 = int(input("Enter your angles :"))

triangle = angles1 + angles2 + angles3 
if triangle ==180 :
    print(f"{triangle} is valid")
else:
    print(f"{triangle} is not valid")
# Out:
# 180 is valid

# %%
# 15. Determine whether a character is uppercase, lowercase, digit, or symbol.
