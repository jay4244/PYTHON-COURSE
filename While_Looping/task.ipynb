# %%
# accept number from check the number is postive or nagative
num = int(input("ENter your number :"))

if num >0:
    print("number is positive ")
else:
    print("number is nagative")
# Out:
# number is positive

# %%
# accept user for voting
age = int(input("ENter your age :"))

if age >= 18:
    print("you are aligalbe for voting") 
else :
    print("you are not aligalbe voting")
# Out:
# you are aligalbe for voting

# %%
# accept from number check number even or odd

num = int(input("Enter your number :"))

if num%2==0:
    print("number is even :",num)
else:
    print("number is odd :",num)
# Out:
# number is odd : 7

# %%
temp = int(input("Enter your temputure :"))

if temp > 100:
    print("temp is air")
elif temp >0:
    print("Temp is liqued")
else:
    print("Temp is nothing")
# Out:
# Temp is liqued

# %%
# accept 5 numbers from user and display perfrom addition operation
sum = 0
for i in range(1,6):
    num = int(input("Enter your number :"))
    sum += num
    
print(sum)
# Out:
# 150
