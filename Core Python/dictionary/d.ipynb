# %%
student = {
    "name": "jay",
    "subject": ["python", "java", "c"],
    "marks": 450,
}

# %%
score = {
    "student1" : "jay",
    "student2" : "jaydeep",
    "student3" : "Aksay"
}
for key, value in score.items():
    print(key, value)
# Out:
# student1 jay
# student2 jaydeep
# student3 Aksay

# %%
Exam = {
    "subject1": "python", "marks1": 450,
    "subject2": "java", "marks2": 400,
    "subject3": "c", "marks3": 350
}
for key, value in Exam.items():
    print(key, value)
# Out:
# subject1 python
# marks1 450
# subject2 java
# marks2 400
# subject3 c
# marks3 350

# %%
l1 = [23,43,56,23,78]
print(l1)

l2 =list(set(l1))
print(l2)
# Out:
# [23, 43, 56, 23, 78]
# [56, 43, 78, 23]
