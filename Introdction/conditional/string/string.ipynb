# %%
name = "jay"
friend = "rohan"
anotherfriend = 'karan'
apple = ''' He said, hi jay Hey i am good "I want to eat an apple" '''
print("Hello," + name)
print(apple)

print(name[0]) 
print(name[1])
print(name[2])
# print(name[3])
# Out:
# Hello,jay
#  He said, hi jay Hey i am good "I want to eat an apple"
# j
# a
# y

# %%
nm = "Harry"
print(nm[-4:-2])
# Out:
# ar

# %%
str = "Tops "
print(" str.isdigit()",str.isdigit())
# Out:
#  str.isdigit() False

# %%
str = "silver spoon"
print(str.split(" "))
# Out:
# ['silver', 'spoon']

# %%
name = "tops techonlogy"
print(name.capitalize())
# Out:
# Tops techonlogy

# %%
str3 = "Hello !!!"
print(str3.rstrip("!"))
# Out:
# Hello

# %%
l1 = [12,23,45,7,0]
print(l1)
l1.remove(23)
print(l1)
# Out:
# [12, 23, 45, 7, 0]
# [12, 45, 7, 0]

# %%
l1 = ["python","java","php","c++"]

print(l1)

l1.pop()

print(l1)
# Out:
# ['python', 'java', 'php', 'c++']
# ['python', 'java', 'php']

# %%
l1 = ["python","java","php","c++"]

print(l1)

l1.pop(1)

print(l1)
# Out:
# ['python', 'java', 'php', 'c++']
# ['python', 'php', 'c++']

# %%
l1 = ["python","java","php","c++"]

print(l1)

l1.pop(-2)

print(l1)
# Out:
# ['python', 'java', 'php', 'c++']
# ['python', 'java', 'c++']

# %%
l1 = [12,23,45,7,0]

print(l1)

l1.clear()

print(l1)
# Out:
# [12, 23, 45, 7, 0]
# []

# %%
l1 = [2,3,4,5,6]

print(l1)

del l1
# Out:
# [2, 3, 4, 5, 6]

# %%
l1 = ["python","java","php","c++"]

print(l1.index("java"))
# Out:
# 1

# %%
l1 = ["python","java","fullter","c++"]

print(l1)

l1.pop(-2)

print(l1)
# Out:
# ['python', 'java', 'fullter', 'c++']
# ['python', 'java', 'c++']

# %%
subject = "we are here"

subject.title()
# Out:
# 'We Are Here'

# %%
str = "we are here"

str.capitalize()
# Out:
# 'We are here'

# %%
str1 = "we are here,where are you"

print(str1)

print(str1.replace("e","i",2))
# Out:
# we are here,where are you
# wi ari here,where are you

# %%
print("--- Example 1: Basic Replacement ---")
original_string = "I love Python. Python is fun. Python is powerful."
new_string_all = original_string.replace("Python", "Gemini")

print(f"Original: {original_string}")
print(f"Replaced: {new_string_all}")
print(f"Original string remains unchanged: {original_string}") # Output: I love Python...
print("-" * 30)
# Out:
# --- Example 1: Basic Replacement ---
# Original: I love Python. Python is fun. Python is powerful.
# Replaced: I love Gemini. Gemini is fun. Gemini is powerful.
# Original string remains unchanged: I love Python. Python is fun. Python is powerful.
# ------------------------------
