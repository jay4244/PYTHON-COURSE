# %%
t = ()

print(t)

print(type(t))
# Out:
# ()
# <class 'tuple'>

# %%
t = ("python","java")

print(t)
print(type(t))

t = ("pyhton")
print(t)
print(type(t))

t = ("python",)
print(t)
print(type(t))
# Out:
# ('python', 'java')
# <class 'tuple'>
# pyhton
# <class 'str'>
# ('python',)
# <class 'tuple'>

# %%
t = ("python","java","c","java")

print(t)

print(len(t))

print(t.count("java"))

print(t.index("python"))
# Out:
# ('python', 'java', 'c', 'java')
# 4
# 2
# 0

# %% [markdown]
# SET EXAMPLE

# %%
s = {"python","java","c","fullter"}

print(s)
# Out:
# {'fullter', 'c', 'python', 'java'}
