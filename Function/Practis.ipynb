# %%
def factorial(n):
    fact = 1
    for i in range(1, n + 1):
        fact *= i
    return fact

num = int(input("Enter a number: "))
result = factorial(num)
print("Factorial of", num, "is", result)
# Out:
# Factorial of 5 is 120

# %%
def number():
    q1 =[0,9,6,8,10,12,34,46,78,82,93]
    averge = q1 / 6
    return averge

averge = number
print(averge)
# Out:
# <function number at 0x000002A0EBDD98A0>

# %%
def factorial(n):
                if n == 1:    
                    return 1
                return n * factorial(n - 1)
print(factorial(5))
# Out:
# 120

# %%
def Find_Even():
    l1 = [2, 4, 7, 13, 33, 46, 58, 69, 77]
    L2 = []

    for num in l1:
        if num % 2 == 0:
            L2.append(num)

    return L2

print(Find_Even())
# Out:
# [2, 4, 46, 58]

# %%
def max():
    num1 = int(input("Enter your number :"))
    num2 = int(input("Enter your number :"))

    return num1>num2 or num2>num1

max()
# Out:
# True
